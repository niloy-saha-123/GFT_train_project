# %% [markdown]
# # 02 Calibration + Markers
#
# Draw ROI, timestamp ignore mask, lane polygon, axis, speed markers.
# Save profile YAML.

# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd() / 'src'))

from rail_video_intelligence.pipeline.calibration import save_interactive_profile

VIDEO_PATH = Path('data/raw/camera_01_2026_04_09_233235.MOV')
PROFILE_PATH = Path('configs/camera_profiles/camera_01.yaml')
CAMERA_ID = 'camera_01'

# %%
# Opens interactive matplotlib prompts.
profile = save_interactive_profile(
    video_path=VIDEO_PATH,
    output_profile_path=PROFILE_PATH,
    camera_id=CAMERA_ID,
    frame_index=0,
)
profile
